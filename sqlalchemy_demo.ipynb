# %% [markdown]
# <a href="https://colab.research.google.com/github/eanxgeek/QECamp19-Intro-to-pandas/blob/master/sqlalchemy_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### This is a very simple demo using sqlalchemy to engage a database and create a dataframe from the query results.

# %%
from sqlalchemy import create_engine
import os
import configparser
import pandas as pd
import numpy as np

# %%
home = os.path.expanduser('~')
cf = home+'/.jira.ini'

config = configparser.ConfigParser()
config.read(cf)

u = config['PGSQL']['username']
p = config['PGSQL']['password']

# %%
prod_uri = f'postgresql://{u}:{p}@polarion-node-01.hosts.prod.upshift.eng.rdu2.redhat.com:5432/polarion'
sql = "SELECT * from polarion.workitem where c_type = 'requirement'"

# %%
engine = create_engine(prod_uri, client_encoding='utf8')

# %%
with engine.connect() as con:
    con.execute('SET search_path TO polarion')
    rs = con.execute(sql)
    df = pd.DataFrame(rs.fetchall())

# %%
df.head()
# Out:
#         0        1        2      3      4      5                       6   \
# 0  6764377  6764377  5772012  False  70898  70898 2018-04-18 23:08:37.794
# 1  6764378  6764378  5772012  False  70898  70898 2018-04-18 23:08:37.893
# 2   216559   216559  5772012  False  70898  70898 2018-04-25 23:08:41.540
# 3  6768024  6768024  5772012  False   4846   4846 2018-09-15 13:14:13.840
# 4  6764382  6764382  5772012  False  70898  70898 2018-05-07 13:19:35.679
#
#                                                   7     8            9   \
# 0  text/html:\n<p>This feature request summaries ...  None  EAP7-298036
# 1                                               None  None  EAP7-298037
# 2  text/html:\n<p>If ee8.preview.mode is set, Wil...  None  EAP7-298315
# 3                                               None  None     POLA-789
# 4  text/html:\n<p>Please see <a href="https://iss...  None  EAP7-298470
#
#             ...              22  23         24        25    26    27  28  \
# ...

# %% [markdown]
# ## Check out these result keys

# %%
rs.keys()
# Out:
# ['c_pk',
#  'c_uri',
#  'c_rev',
#  'c_deleted',
#  'fk_author',
#  'fk_uri_author',
#  'c_created',
#  'c_description',
#  'c_duedate',
#  'c_id',
#  'c_initialestimate',
#  'c_location',
#  'fk_module',
#  'fk_uri_module',
#  'c_outlinenumber',
#  'c_plannedend',
#  'c_plannedstart',
#  'c_previousstatus',
#  'c_priority',
#  'fk_project',
#  'fk_uri_project',
#  'c_remainingestimate',
#  'c_resolution',
#  'c_resolvedon',
#  'c_severity',
#  'c_status',
#  'fk_timepoint',
#  'fk_uri_timepoint',
#  'c_timespent',
#  'c_title',
#  'c_type',
#  'c_updated']

# %% [markdown]
# ## Convert the dataframe columns to rs.keys

# %%
df.columns = rs.keys()

# %%
df.head()
# Out:
#       c_pk    c_uri    c_rev  c_deleted  fk_author  fk_uri_author  \
# 0  6764378  6764378  5772012      False      70898          70898
# 1  6768024  6768024  5772012      False       4846           4846
# 2  6764382  6764382  5772012      False      70898          70898
# 3  6764431  6764431  5782509      False      70898          70898
# 4   214649   214649  5782509      False      70898          70898
#
#                 c_created                                      c_description  \
# 0 2018-04-18 23:08:37.893                                               None
# 1 2018-09-15 13:14:13.840                                               None
# 2 2018-05-07 13:19:35.679  text/html:\n<p>Please see <a href="https://iss...
# 3 2018-06-13 23:08:43.389  text/html:\nWeb console part of <a class="issu...
# 4 2018-06-13 23:08:43.477  text/html:\nSupport Eclipse MicroProfile Confi...
#
#   c_duedate         c_id           ...            c_resolution c_resolvedon  \
# ...

# %% [markdown]
# ## Let's replace None with NumPy's NaN

# %%
df.fillna(value=pd.np.nan, inplace=True)

# %%
df.head()
# Out:
#       c_pk    c_uri    c_rev  c_deleted  fk_author  fk_uri_author  \
# 0  6764378  6764378  5772012      False      70898          70898
# 1  6768024  6768024  5772012      False       4846           4846
# 2  6764382  6764382  5772012      False      70898          70898
# 3  6764431  6764431  5782509      False      70898          70898
# 4   214649   214649  5782509      False      70898          70898
#
#                 c_created                                      c_description  \
# 0 2018-04-18 23:08:37.893                                                NaN
# 1 2018-09-15 13:14:13.840                                                NaN
# 2 2018-05-07 13:19:35.679  text/html:\n<p>Please see <a href="https://iss...
# 3 2018-06-13 23:08:43.389  text/html:\nWeb console part of <a class="issu...
# 4 2018-06-13 23:08:43.477  text/html:\nSupport Eclipse MicroProfile Confi...
#
#   c_duedate         c_id           ...            c_resolution c_resolvedon  \
# ...
